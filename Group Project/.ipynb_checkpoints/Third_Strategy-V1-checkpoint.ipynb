# %%
import pandas as pd
import yfinance as yf  # Yahoo Finance API for fetching stock data
import matplotlib.pyplot as plt
import numpy as np

# %%
# Define MAANG stocks and time period
tickers = ['META', 'AAPL', 'AMZN', 'NFLX', 'GOOGL']
start_date = '2014-12-01'
end_date = '2019-12-31'

columns_to_drop = ['High', 'Low', 'Dividends', 'Stock Splits']
result_df = pd.DataFrame()

for each_stock in tickers:
    stock_data = yf.Ticker(each_stock)
    hist_stock_data = stock_data.history(start = start_date, end = end_date)
    hist_stock_data_copy = hist_stock_data.copy()
    hist_stock_data_copy = hist_stock_data_copy.drop(columns_to_drop, axis=1)
    hist_stock_data_copy.columns = [each_stock + '_' + col for col in hist_stock_data_copy.columns]
    result_df = pd.concat([result_df, hist_stock_data_copy], axis=1)

# %%
#calculate stochastic oscillator
def calculate_SO(df, window_size_K, window_size_D ):
    
    for each_stock in tickers:
        stock_close_column = each_stock + '_Close'
        stock_SO_K = each_stock + '_SO_K'
        stock_SO_D = each_stock + '_SO_D'
        stock_Highest_L14 = each_stock + '_Highest_in_L14'
        stock_Lowest_L14 = each_stock + '_Lowest_in_L14'
        stock_recent_price = each_stock + '_recent_price'
        stock_SO_Buy_Sell_decision = each_stock + '_SO_B/S_Decision'
        df[stock_Highest_L14] = df[stock_close_column].rolling(window=window_size_K).max()
        df[stock_Lowest_L14] = df[stock_close_column].rolling(window=window_size_K).min()
        df[stock_recent_price] = df[stock_close_column]
        df[stock_SO_K] = ((df[stock_recent_price] - df[stock_Lowest_L14])/(df[stock_Highest_L14] - df[stock_Lowest_L14])) * 100 
        df[stock_SO_D] = df[stock_SO_K].rolling(window=window_size_D).mean()
        conditions = [(df[stock_SO_D] < 20),(df[stock_SO_D] > 80)]
        choices = ['Buy','Sell']
        df[stock_SO_Buy_Sell_decision] = np.select(conditions, choices, default='NA')
        temp_columns = [stock_Highest_L14, stock_Lowest_L14, stock_recent_price]
        df = df.drop(temp_columns, axis=1)
    return df

# %%
#calculate MACD
def calculate_MACD(df):
    for each_stock in tickers:
        stock_close_column = each_stock + '_Close'
        stock_MACD = each_stock + '_MACD'
        stock_signal_MACD = each_stock + '_signal_MACD'
        stock_signal_MACD_diff = each_stock + '_signal_MACD_diff'
        stock_MACD_Buy_Sell_decision = each_stock + '_MACD_B/S_Decision'
        Short_EMA = df[stock_close_column].ewm(span=12, adjust=False).mean()
        Long_EMA = df[stock_close_column].ewm(span=26, adjust=False).mean()
        MACD = Short_EMA - Long_EMA
        signal = MACD.ewm(span=9, adjust=False).mean()
        df[stock_MACD] = MACD
        df[stock_signal_MACD] = signal
        df[stock_signal_MACD_diff] = df[stock_MACD] - df[stock_signal_MACD]
        conditions = [
            (df[stock_signal_MACD_diff] > 0) & (df[stock_signal_MACD_diff].shift(1) < 0), 
            (df[stock_signal_MACD_diff] < 0) & (df[stock_signal_MACD_diff].shift(1) > 0) 
        ]
        choices = ['Buy','Sell']
        df[stock_MACD_Buy_Sell_decision] = np.select(conditions, choices, default='NA')   
    return df

# %%
#finalise Buy/Sell
def final_buy_sell(df):
    for each_stock in tickers:
        stock_SO_Buy_Sell_decision = each_stock + '_SO_B/S_Decision'
        stock_MACD_Buy_Sell_decision = each_stock + '_MACD_B/S_Decision'
        stock_Final_BorS_Decision = each_stock + '_Final_BorS_Decision'
        conditions = [
            (df[stock_SO_Buy_Sell_decision] == "Buy") & (df[stock_MACD_Buy_Sell_decision] == "Buy"), 
            (df[stock_SO_Buy_Sell_decision] == "Sell") & (df[stock_MACD_Buy_Sell_decision] == "Sell")
        ]
        choices = ['Buy','Sell']
        df[stock_Final_BorS_Decision] = np.select(conditions, choices, default='NA')
    return df

# %%
result_df = calculate_SO(result_df, 14, 3)
result_df = calculate_MACD(result_df)
result_df = final_buy_sell(result_df)

# %%
for each_stock in tickers:
    stock_Final_BorS_Decision = each_stock + '_Final_BorS_Decision'
    print(each_stock)
    print(result_df[stock_Final_BorS_Decision].value_counts())
# Out:
# META
# NA      1269
# Sell       8
# Buy        2
# Name: META_Final_BorS_Decision, dtype: int64
# AAPL
# NA      1266
# Sell      11
# Buy        2
# Name: AAPL_Final_BorS_Decision, dtype: int64
# AMZN
# NA      1270
# Sell       9
# Name: AMZN_Final_BorS_Decision, dtype: int64
# NFLX
# NA      1270
# Sell       9
# Name: NFLX_Final_BorS_Decision, dtype: int64
# GOOGL
# NA      1273
# Sell       5
# Buy        1
# Name: GOOGL_Final_BorS_Decision, dtype: int64

# %%
#Buy and selling of shares following the strategy based on the B/S signals from SO and MACD
def execute_buy_sell(df):
    df.index = pd.to_datetime(df.index)
    df['Cash Balance'] = 0
    initial_date = pd.Timestamp('2015-01-02')
    initial_date = initial_date.tz_localize(None)
    #df.loc['2015-01-02', 'Cash balance'] = 1000000
    
    #Add columns for shares owned & initial allocation
    for stock in tickers:
        df[stock + '_owned_shares'] = 0 
        if stock + '_Open' in df.columns:  
            initial_price = df.loc['2015-01-02', stock + '_Open']
            #print(initial_price)
            df.loc['2015-01-02', stock + '_owned_shares'] = round(200000 / initial_price)

    start_index = df.index.get_loc(initial_date) + 1
    
    # Iterate over the DataFrame for next day execution based on the previous day's decisions
    for i in range(start_index, len(df.index)):
        current_date = df.index[i]
        previous_date = df.index[i - 1]

        # Initialize daily cash balance based on the previous day's ending balance
        daily_cash_balance = df.at[previous_date, 'Cash Balance']

        buy_stocks = []
        sell_stocks = []

        for stock in tickers:
            decision_column = stock + '_Final_BorS_Decision'  # Adjust based on actual column names
            if df.at[previous_date, decision_column] == 'Buy':
                #print(current_date, " - Buy - " ,stock)
                buy_stocks.append(stock)
            elif df.at[previous_date, decision_column] == 'Sell':
                #print(current_date, " - Sell - " , stock)
                sell_stocks.append(stock)
        
        # Execute sells first to update the cash balance
        if sell_stocks:
            for stock in sell_stocks:
                print(current_date, " - Sell - " ,stock)
                sell_price = df.at[current_date, stock + '_Open']
                print("Selling price ", sell_price)
                shares_to_sell = df.at[previous_date, stock + '_owned_shares']
                print("Previous date ", previous_date)
                print("Stocks owned on previous date (shares to sell): ", shares_to_sell)
                daily_cash_balance = daily_cash_balance + (sell_price * shares_to_sell) # Increase cash balance
                print("Cash Balance after selling shares: ", daily_cash_balance)
                df.at[current_date, stock + '_owned_shares'] = 0  # Reset shares to 0 after selling
                print("Shares owned on current date after selling: ", df.at[current_date, stock + '_owned_shares'])   
            if not buy_stocks:
                all_stocks = set(tickers)
                sell_set = set(sell_stocks)
                not_sell = all_stocks - sell_set
                buy_stocks = list(not_sell)
                print("Not sell stocks: ",not_sell)
                print("buy_stocks list after selling shares: ",buy_stocks)
        # Execute buys with the updated cash balance
        if buy_stocks:
            cash_per_stock = daily_cash_balance / len(buy_stocks) if daily_cash_balance > 0 else 0
            for stock in buy_stocks:
                if cash_per_stock > 0:
                    print(current_date, " - Buy - " ,stock)
                    buy_price = df.at[current_date, stock + '_Open']
                    print("Buying price ", buy_price)
                    shares_to_buy = round(cash_per_stock / buy_price)
                    print("Previous date ", previous_date)
                    print("Stocks owned on previous date: ", df.at[previous_date, stock + '_owned_shares'])
                    print("Shares to buy: ", shares_to_buy)
                    df.at[current_date, stock + '_owned_shares'] = df.at[previous_date, stock + '_owned_shares'] + shares_to_buy  # Add bought shares
                    print("Shares owned after buying: ", df.at[current_date, stock + '_owned_shares'])
                    daily_cash_balance = daily_cash_balance - (shares_to_buy * buy_price)  # Deduct spent cash
                else:
                    df.at[current_date, stock + '_owned_shares'] = df.at[previous_date, stock + '_owned_shares']
                    
        all_stocks = set(tickers)
        buy_set = set(buy_stocks)
        sell_set = set(sell_stocks)
        
        no_transaction_stocks = all_stocks - (buy_set.union(sell_set))
        print(current_date, 'No transaction stocks : ' , no_transaction_stocks)
        for stock in no_transaction_stocks:
            df.at[current_date, stock + '_owned_shares'] = df.at[previous_date, stock + '_owned_shares']

        # Update the cash balance at the end of the day
        df.at[current_date, 'Cash Balance'] = daily_cash_balance
    
    return df

# %%
#Calculation of the Portfolio value if 1M is invested through the Strategy 2: Defensive Entry Points
def calculate_portfolio_value(df):
    df.index = pd.to_datetime(df.index)
    df['Portfolio Value'] = 0
    initial_date = pd.Timestamp('2015-01-02')
    initial_date = initial_date.tz_localize(None)
    start_index = df.index.get_loc(initial_date)
    
    portfolio_value = 0
    current_date = df.index[start_index]
    #calculating the portfolio value on day 1 - 2015/01/02
    for stock in tickers:
        stock_value = df.at[current_date, stock + '_owned_shares'] * df.at[current_date, stock +'_Close']
        portfolio_value = portfolio_value + stock_value
    df.at[current_date, 'Portfolio Value'] = portfolio_value
    
    start_index = df.index.get_loc(initial_date) + 1
    
    # len(df.index)
    for i in range(start_index, len(df.index)): 
        portfolio_value = 0
        current_date = df.index[i]
        #print(current_date)
        for stock in tickers:
            stock_value = df.at[current_date, stock + '_owned_shares'] * df.at[current_date, stock +'_Close']
            portfolio_value = portfolio_value + stock_value
            #print(current_date, ' ', portfolio_value)
        #print(portfolio_value)
        df.at[current_date, 'Portfolio Value'] = portfolio_value
    
    return df

# %%
#Removal of initial few rows (out of our required period) which were used for the SO and MACD calculation
def remove_unnecessary_initial_rows(df):
    df.index = pd.to_datetime(df.index)
    initial_date = pd.Timestamp('2015-01-02')
    df = df.loc[initial_date:]
    return df

# %%
result_df = execute_buy_sell(result_df)
# Out:
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_1549/898819920.py:17: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   start_index = df.index.get_loc(initial_date) + 1
# 2015-01-05 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-06 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-07 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-08 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-09 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-12 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-13 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-14 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-15 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-16 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-20 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-21 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-22 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-23 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-26 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-27 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-28 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-29 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-01-30 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-02 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-03 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-05 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-06 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-09 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-10 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-12 00:00:00-05:00  - Sell -  NFLX
# Selling price  65.0585708618164
# Previous date  2015-02-11 00:00:00-05:00
# Stocks owned on previous date (shares to sell):  4069
# Cash Balance after selling shares:  264723.32483673096
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'META', 'GOOGL', 'AMZN'}
# buy_stocks list after selling shares:  ['AAPL', 'META', 'GOOGL', 'AMZN']
# 2015-02-12 00:00:00-05:00  - Buy -  AAPL
# Buying price  28.285620614682113
# Previous date  2015-02-11 00:00:00-05:00
# Stocks owned on previous date:  8034
# Shares to buy:  2340
# Shares owned after buying:  10374
# 2015-02-12 00:00:00-05:00  - Buy -  META
# Buying price  76.7785375955525
# Previous date  2015-02-11 00:00:00-05:00
# Stocks owned on previous date:  2548
# Shares to buy:  862
# Shares owned after buying:  3410
# 2015-02-12 00:00:00-05:00  - Buy -  GOOGL
# Buying price  26.982999801635742
# Previous date  2015-02-11 00:00:00-05:00
# Stocks owned on previous date:  7510
# Shares to buy:  2453
# Shares owned after buying:  9963
# 2015-02-12 00:00:00-05:00  - Buy -  AMZN
# Buying price  18.7549991607666
# Previous date  2015-02-11 00:00:00-05:00
# Stocks owned on previous date:  12797
# Shares to buy:  3529
# Shares owned after buying:  16326
# 2015-02-12 00:00:00-05:00 No transaction stocks :  set()
# 2015-02-13 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-17 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-18 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-19 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-20 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-23 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-24 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-02-25 00:00:00-05:00  - Sell -  AMZN
# Selling price  18.863500595092773
# Previous date  2015-02-24 00:00:00-05:00
# Stocks owned on previous date (shares to sell):  16326
# Cash Balance after selling shares:  307941.6933547354
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'META', 'GOOGL', 'NFLX'}
# buy_stocks list after selling shares:  ['AAPL', 'META', 'GOOGL', 'NFLX']
# 2015-02-25 00:00:00-05:00  - Buy -  AAPL
# Buying price  29.519715720332034
# Previous date  2015-02-24 00:00:00-05:00
# Stocks owned on previous date:  10374
# Shares to buy:  2608
# Shares owned after buying:  12982
# 2015-02-25 00:00:00-05:00  - Buy -  META
# Buying price  78.41679582105559
# Previous date  2015-02-24 00:00:00-05:00
# Stocks owned on previous date:  3410
# Shares to buy:  982
# Shares owned after buying:  4392
# 2015-02-25 00:00:00-05:00  - Buy -  GOOGL
# Buying price  26.922000885009766
# Previous date  2015-02-24 00:00:00-05:00
# Stocks owned on previous date:  9963
# Shares to buy:  2860
# Shares owned after buying:  12823
# 2015-02-25 00:00:00-05:00  - Buy -  NFLX
# Buying price  67.80714416503906
# Previous date  2015-02-24 00:00:00-05:00
# Stocks owned on previous date:  0
# Shares to buy:  1135
# Shares owned after buying:  1135
# 2015-02-25 00:00:00-05:00 No transaction stocks :  set()
# 2015-02-26 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015
00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-27 00:00:00-04:00  - Sell -  NFLX
# Selling price  88.14286041259766
# Previous date  2015-05-26 00:00:00-04:00
# Stocks owned on previous date (shares to sell):  0
# Cash Balance after selling shares:  -8.355980053253006
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'META', 'GOOGL', 'AMZN'}
# buy_stocks list after selling shares:  ['AAPL', 'META', 'GOOGL', 'AMZN']
# 2015-05-27 00:00:00-04:00 No transaction stocks :  set()
# 2015-05-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-05-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-06-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-07-31 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-10 00:00:00-04:00  - Sell -  AMZN
# Selling price  26.426000595092773
# Previous date  2015-08-07 00:00:00-04:00
# Stocks owned on previous date (shares to sell):  6314
# Cash Balance after selling shares:  166845.41177736252
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'META', 'GOOGL', 'NFLX'}
# buy_stocks list after selling shares:  ['AAPL', 'META', 'GOOGL', 'NFLX']
# 2015-08-10 00:00:00-04:00  - Buy -  AAPL
# Buying price  26.375322323876127
# Previous date  2015-08-07 00:00:00-04:00
# Stocks owned on previous date:  17684
# Shares to buy:  1581
# Shares owned after buying:  19265
# 2015-08-10 00:00:00-04:00  - Buy -  META
# Buying price  95.57859388535104
# Previous date  2015-08-07 00:00:00-04:00
# Stocks owned on previous date:  587
# Shares to buy:  436
# Shares owned after buying:  1023
# 2015-08-10 00:00:00-04:00  - Buy -  GOOGL
# Buying price  33.35449981689453
# Previous date  2015-08-07 00:00:00-04:00
# Stocks owned on previous date:  17627
# Shares to buy:  1251
# Shares owned after buying:  18878
# 2015-08-10 00:00:00-04:00  - Buy -  NFLX
# Buying price  126.08999633789062
# Previous date  2015-08-07 00:00:00-04:00
# Stocks owned on previous date:  0
# Shares to buy:  331
# Shares owned after buying:  331
# 2015-08-10 00:00:00-04:00 No transaction stocks :  set()
# 2015-08-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-19 00:00:00-04:00  - Sell -  NFLX
# Selling price  123.5
# Previous date  2015-08-18 00:00:00-04:00
# Stocks owned on previous date (shares to sell):  331
# Cash Balance after selling shares:  40889.992190524456
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'META', 'GOOGL', 'AMZN'}
# buy_stocks list after selling shares:  ['AAPL', 'META', 'GOOGL', 'AMZN']
# 2015-08-19 00:00:00-04:00  - Buy -  AAPL
# Buying price  26.277997200304963
# Previous date  2015-08-18 00:00:00-04:00
# Stocks owned on previous date:  19265
# Shares to buy:  389
# Shares owned after buying:  19654
# 2015-08-19 00:00:00-04:00  - Buy -  META
# Buying price  94.5296971852143
# Previous date  2015-08-18 00:00:00-04:00
# Stocks owned on previous date:  1023
# Shares to buy:  108
# Shares owned after buying:  1131
# 2015-08-19 00:00:00-04:00  - Buy -  GOOGL
# Buying price  34.50550079345703
# Previous date  2015-08-18 00:00:00-04:00
# Stocks owned on previous date:  18878
# Shares to buy:  296
# Shares owned after buying:  19174
# 2015-08-19 00:00:00-04:00  - Buy -  AMZN
# Buying price  26.687000274658203
# Previous date  2015-08-18 00:00:00-04:00
# Stocks owned on previous date:  0
# Shares to buy:  383
# Shares owned after buying:  383
# 2015-08-19 00:00:00-04:00 No transaction stocks :  set()
# 2015-08-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-08-31 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-09-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-10-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-02 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-03 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-05 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-06 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-09 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-10 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-12 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-13 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-16 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-17 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-18 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-19 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-20 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-23 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-24 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-25 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-27 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-11-30 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-01 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-02 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-03 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-07 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-08 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-09 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-10 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-14 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-15 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-16 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-17 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-18 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-21 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-22 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-23 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-24 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-28 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-29 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-30 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2015-12-31 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-05 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-06 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-07 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-08 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-12 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-13 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-14 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-15 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-19 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-20 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-21 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-22 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-25 00:00:00-05:00  - Buy -  AAPL
# Buying price  23.076322893895085
# Previous date  2016-01-22 00:00:00-05:00
# Stocks owned on previous date:  19654
# Shares to buy:  1
# Shares owned after buying:  19655
# 2016-01-25 00:00:00-05:00 No transaction stocks :  {'META', 'GOOGL', 'NFLX', 'AMZN'}
# 2016-01-26 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-27 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-28 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-01-29 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-01 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-02 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-03 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-05 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-08 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-09 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-10 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-12 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-16 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-17 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-18 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-19 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-22 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-23 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-24 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-25 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-26 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-02-29 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-01 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-02 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-03 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-07 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-08 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-09 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-10 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-03-31 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-18 00:00:00-04:00  - Sell -  AAPL
# Selling price  24.885898653981737
# Previous date  2016-04-15 00:00:00-04:00
# Stocks owned on previous date (shares to sell):  19655
# Cash Balance after selling shares:  489133.15636466246
# Shares owned on current date after selling:  0
# Not sell stocks:  {'META', 'GOOGL', 'NFLX', 'AMZN'}
# buy_stocks list after selling shares:  ['META', 'GOOGL', 'NFLX', 'AMZN']
# 2016-04-18 00:00:00-04:00  - Buy -  META
# Buying price  109.62368495875563
# Previous date  2016-04-15 00:00:00-04:00
# Stocks owned on previous date:  1131
# Shares to buy:  1115
# Shares owned after buying:  2246
# 2016-04-18 00:00:00-04:00  - Buy -  GOOGL
# Buying price  39.009498596191406
# Previous date  2016-04-15 00:00:00-04:00
# Stocks owned on previous date:  19174
# Shares to buy:  3135
# Shares owned after buying:  22309
# 2016-04-18 00:00:00-04:00  - Buy -  NFLX
# Buying price  109.9000015258789
# Previous date  2016-04-15 00:00:00-04:00
# Stocks owned on previous date:  0
# Shares to buy:  1113
# Shares owned after buying:  1113
# 2016-04-18 00:00:00-04:00  - Buy -  AMZN
# Buying price  31.267499923706055
# Previous date  2016-04-15 00:00:00-04:00
# Stocks owned on previous date:  383
# Shares to buy:  3911
# Shares owned after buying:  4294
# 2016-04-18 00:00:00-04:00 No transaction stocks :  set()
# 2016-04-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-04-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-05-31 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-06-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-07-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2016-08-15 00:00:00-04:00  - Sell -  META
# Selling price  124.77761605863566
# Previous date  2016-08-12 00:00:00-04:00
# Stocks owned on previous date (shares to sell):  2246
# Cash Balance after selling shares:  280252.60130436794
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'GOOGL', 'NFLX', 'AMZN'}
# buy_stocks list after selling shares:  ['AAPL', 'GOOGL', 'NFLX', 'AMZN']
# 2016-08-15 00:00:00-04:00  - Buy -  AAPL
# Buying price  24.999665941538147
# Previous date  2016-08-12 00:00:00-04:00
# Stocks owned on previous date:  0
# Shares to buy:  2803
# Shares owned after buying:  2803
# 2016-08-15 00:00:00-04:00  - Buy -  GOOGL
# Buying price  40.36050033569336
# Previous date  2016-08-12 00:00:00-04:00
# Stocks owned on previous date:  22309
# Shares to buy:  1736
# Shares owned after buying:  24045
# 2016-08-15 00:00:00-04:00  - Buy -  NFLX
# Buying price  96.83000183105469
# Previous date  2016-08-12 00:00:00-04:00
# Stocks owned on previous date:  1113
# Shares to buy:  724
# Shares owned after buying:  1837
# 2016-08-15 00:00:00-04:00  - Buy -  AMZN
# Buying price  38.595001220703125
# ...
# 2019-06-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-06-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-06-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-18 00:00:00-04:00  - Sell -  AAPL
# Selling price  49.28671899240652
# Previous date  2019-07-17 00:00:00-04:00
# Stocks owned on previous date (shares to sell):  0
# Cash Balance after selling shares:  -28.473904591228347
# Shares owned on current date after selling:  0
# Not sell stocks:  {'META', 'GOOGL', 'NFLX', 'AMZN'}
# buy_stocks list after selling shares:  ['META', 'GOOGL', 'NFLX', 'AMZN']
# 2019-07-18 00:00:00-04:00 No transaction stocks :  set()
# 2019-07-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-07-31 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-08-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-05 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-06 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-12 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-13 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-19 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-20 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-26 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-27 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-09-30 00:00:00-04:00  - Sell -  GOOGL
# Selling price  61.029998779296875
# Previous date  2019-09-27 00:00:00-04:00
# Stocks owned on previous date (shares to sell):  34677
# Cash Balance after selling shares:  2116308.7937650867
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'META', 'AMZN', 'NFLX'}
# buy_stocks list after selling shares:  ['AAPL', 'META', 'AMZN', 'NFLX']
# 2019-09-30 00:00:00-04:00  - Buy -  AAPL
# Buying price  53.57255625171346
# Previous date  2019-09-27 00:00:00-04:00
# Stocks owned on previous date:  0
# Shares to buy:  9876
# Shares owned after buying:  9876
# 2019-09-30 00:00:00-04:00  - Buy -  META
# Buying price  177.68146648758494
# Previous date  2019-09-27 00:00:00-04:00
# Stocks owned on previous date:  7043
# Shares to buy:  2978
# Shares owned after buying:  10021
# 2019-09-30 00:00:00-04:00  - Buy -  AMZN
# Buying price  86.34950256347656
# Previous date  2019-09-27 00:00:00-04:00
# Stocks owned on previous date:  947
# Shares to buy:  6127
# Shares owned after buying:  7074
# 2019-09-30 00:00:00-04:00  - Buy -  NFLX
# Buying price  264.0
# Previous date  2019-09-27 00:00:00-04:00
# Stocks owned on previous date:  1719
# Shares to buy:  2004
# Shares owned after buying:  3723
# 2019-09-30 00:00:00-04:00 No transaction stocks :  set()
# 2019-10-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-02 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-03 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-04 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-07 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-08 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-09 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-10 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-11 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-14 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-15 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-16 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-17 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-18 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-21 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-22 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-23 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-24 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-25 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-28 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-29 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-30 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-10-31 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-01 00:00:00-04:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-05 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-06 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-07 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-08 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-12 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-13 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-14 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-15 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-18 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-19 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-20 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-21 00:00:00-05:00  - Sell -  AAPL
# Selling price  64.14196107651007
# Previous date  2019-11-20 00:00:00-05:00
# Stocks owned on previous date (shares to sell):  9876
# Cash Balance after selling shares:  633437.4264083292
# Shares owned on current date after selling:  0
# Not sell stocks:  {'META', 'GOOGL', 'NFLX', 'AMZN'}
# buy_stocks list after selling shares:  ['META', 'GOOGL', 'NFLX', 'AMZN']
# 2019-11-21 00:00:00-05:00  - Buy -  META
# Buying price  197.2107608590479
# Previous date  2019-11-20 00:00:00-05:00
# Stocks owned on previous date:  10021
# Shares to buy:  803
# Shares owned after buying:  10824
# 2019-11-21 00:00:00-05:00  - Buy -  GOOGL
# Buying price  64.9625015258789
# Previous date  2019-11-20 00:00:00-05:00
# Stocks owned on previous date:  0
# Shares to buy:  2438
# Shares owned after buying:  2438
# 2019-11-21 00:00:00-05:00  - Buy -  NFLX
# Buying price  306.0
# Previous date  2019-11-20 00:00:00-05:00
# Stocks owned on previous date:  3723
# Shares to buy:  518
# Shares owned after buying:  4241
# 2019-11-21 00:00:00-05:00  - Buy -  AMZN
# Buying price  87.1500015258789
# Previous date  2019-11-20 00:00:00-05:00
# Stocks owned on previous date:  7074
# Shares to buy:  1817
# Shares owned after buying:  8891
# 2019-11-21 00:00:00-05:00 No transaction stocks :  set()
# 2019-11-22 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-25 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-26 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-27 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-11-29 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-02 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-03 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-04 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-05 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-06 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-09 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-10 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-11 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-12 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-13 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-16 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-17 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-18 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-19 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-20 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-23 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-24 00:00:00-05:00  - Sell -  GOOGL
# Selling price  67.510498046875
# Previous date  2019-12-23 00:00:00-05:00
# Stocks owned on previous date (shares to sell):  2438
# Cash Balance after selling shares:  164429.6481841802
# Shares owned on current date after selling:  0
# Not sell stocks:  {'AAPL', 'META', 'AMZN', 'NFLX'}
# buy_stocks list after selling shares:  ['AAPL', 'META', 'AMZN', 'NFLX']
# 2019-12-24 00:00:00-05:00  - Buy -  AAPL
# Buying price  69.25014697561615
# Previous date  2019-12-23 00:00:00-05:00
# Stocks owned on previous date:  0
# Shares to buy:  594
# Shares owned after buying:  594
# 2019-12-24 00:00:00-05:00  - Buy -  META
# Buying price  206.08134513165749
# Previous date  2019-12-23 00:00:00-05:00
# Stocks owned on previous date:  10824
# Shares to buy:  199
# Shares owned after buying:  11023
# 2019-12-24 00:00:00-05:00  - Buy -  AMZN
# Buying price  89.69049835205078
# Previous date  2019-12-23 00:00:00-05:00
# Stocks owned on previous date:  8891
# Shares to buy:  458
# Shares owned after buying:  9349
# 2019-12-24 00:00:00-05:00  - Buy -  NFLX
# Buying price  334.010009765625
# Previous date  2019-12-23 00:00:00-05:00
# Stocks owned on previous date:  4241
# Shares to buy:  123
# Shares owned after buying:  4364
# 2019-12-24 00:00:00-05:00 No transaction stocks :  set()
# 2019-12-26 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-27 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}
# 2019-12-30 00:00:00-05:00 No transaction stocks :  {'GOOGL', 'AMZN', 'AAPL', 'META', 'NFLX'}

# %%
result_df = calculate_portfolio_value(result_df)
# Out:
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_1549/3152976944.py:7: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   start_index = df.index.get_loc(initial_date)
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_1549/3152976944.py:17: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   start_index = df.index.get_loc(initial_date) + 1

# %%
#Removal of initial few rows (out of our required period) which were used for the SO and MACD calculation
result_df = remove_unnecessary_initial_rows(result_df)
print(len(result_df))
# Out:
# 1257
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_1549/1369410887.py:5: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   df = df.loc[initial_date:]

# %%
#Calculation of the portfolio value if 1M had been invested equally in the start of the specified period
def calculate_no_strategy_portfolio_value(df):
    for stock in tickers:
        stock_initial_owned = stock + 'initial_owned'
        stock_initial_owned = result_df.at[result_df.index[0], stock + '_owned_shares']
        print("Initial stocks owned: ", stock_initial_owned) 
    
    df.index = pd.to_datetime(df.index)
    df['NS Portfolio Value'] = 0
    initial_date = pd.Timestamp('2015-01-02')
    initial_date = initial_date.tz_localize(None)
    start_index = df.index.get_loc(initial_date)
    
    for i in range(start_index, len(df.index)): 
        ns_portfolio_value = 0
        current_date = df.index[i]
        #print(current_date)
        for stock in tickers:
            stock_initial_owned = stock + 'initial_owned'
            stock_initial_owned = result_df.at[result_df.index[0], stock + '_owned_shares']
            #print("Initial stocks owned: ", stock_initial_owned)
            stock_value = stock_initial_owned * df.at[current_date, stock +'_Close']
            ns_portfolio_value = ns_portfolio_value + stock_value
            #print(current_date, ' ', portfolio_value)
            #print(portfolio_value)
        print("NS Portfolio Value: ", ns_portfolio_value)
        df.at[current_date, 'NS Portfolio Value'] = ns_portfolio_value
    return df

# %%
result_df = calculate_no_strategy_portfolio_value(result_df)
# Out:
# /var/folders/l_/xlcq7dfs5hb1cq7xjkkmbzr40000gn/T/ipykernel_1549/200953070.py:12: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version. Use a timezone-aware object instead.
#   start_index = df.index.get_loc(initial_date)
# Initial stocks owned:  2548
# Initial stocks owned:  8034
# Initial stocks owned:  12797
# Initial stocks owned:  4069
# Initial stocks owned:  7510
# NS Portfolio Value:  995078.1032419205
# NS Portfolio Value:  968177.8643980026
# NS Portfolio Value:  953023.9662361145
# NS Portfolio Value:  958124.9949817657
# NS Portfolio Value:  976912.031586647
# NS Portfolio Value:  968419.3523178101
# NS Portfolio Value:  949880.7263803482
# NS Portfolio Value:  957728.969906807
# NS Portfolio Value:  957413.9256687164
# NS Portfolio Value:  941343.1895637512
# NS Portfolio Value:  955469.8695116043
# NS Portfolio Value:  968704.3823165894
# NS Portfolio Value:  1015544.7526788712
# NS Portfolio Value:  1048828.4174661636
# NS Portfolio Value:  1058641.7907800674
# NS Portfolio Value:  1059596.3166561127
# NS Portfolio Value:  1044837.9621334076
# NS Portfolio Value:  1045174.1963891983
# NS Portfolio Value:  1062215.0884695053
# NS Portfolio Value:  1089094.2534618378
# NS Portfolio Value:  1093318.9657974243
# NS Portfolio Value:  1103436.1806278229
# NS Portfolio Value:  1098947.4688339233
# NS Portfolio Value:  1107793.9798851013
# NS Portfolio Value:  1102197.0740623474
# NS Portfolio Value:  1098687.4658432007
# NS Portfolio Value:  1116713.6267871857
# NS Portfolio Value:  1126333.6927185059
# NS Portfolio Value:  1133845.5551128387
# NS Portfolio Value:  1144078.1336593628
# NS Portfolio Value:  1140913.239566803
# NS Portfolio Value:  1146103.2159748077
# NS Portfolio Value:  3804863.495765686
# NS Portfolio Value:  3814747.039352417
# NS Portfolio Value:  3813131.6393051147
# NS Portfolio Value:  3819864.442375183
# NS Portfolio Value:  3768984.87638855
# NS Portfolio Value:  3797619.6332702637
# NS Portfolio Value:  3830183.929473877
# NS Portfolio Value:  3872536.25894928
# NS Portfolio Value:  3873406.5032577515
# NS Portfolio Value:  3864483.385154724
# NS Portfolio Value:  3882247.8622665405
# NS Portfolio Value:  3883755.586151123
# NS Portfolio Value:  3938311.5837402344
# NS Portfolio Value:  3937252.809814453
# NS Portfolio Value:  3979374.735939026
# NS Portfolio Value:  3957787.148765564
# NS Portfolio Value:  3909804.353805542
# NS Portfolio Value:  3877535.9439849854
# NS Portfolio Value:  3877399.776123047
# NS Portfolio Value:  3870697.7865753174
# NS Portfolio Value:  3915077.1142425537
# NS Portfolio Value:  3888688.4939193726
# NS Portfolio Value:  3845745.5658340454
# NS Portfolio Value:  3883995.3802108765
# NS Portfolio Value:  3878346.2857894897
# NS Portfolio Value:  3878863.8538513184
# NS Portfolio Value:  3931484.819618225
# NS Portfolio Value:  3991156.7944259644
# NS Portfolio Value:  4016594.331352234
# NS Portfolio Value:  4079650.5207366943
# NS Portfolio Value:  4092512.5352783203
# NS Portfolio Value:  4089593.5252609253
# NS Portfolio Value:  4083077.004234314
# NS Portfolio Value:  4156256.2878494263
# NS Portfolio Value:  4140144.928703308
# NS Portfolio Value:  4090330.17137146

# %%
#calculation of portfolio value if 1M was invested in the S&P index at the start of the specified period
def calculate_SP_500_value(df):
    ticker_symbol = "^GSPC"
    start_date = "2015-01-01"
    end_date = "2019-12-31"
    sp500_data = yf.download(ticker_symbol, start=start_date, end=end_date)
    sp500_data.index = pd.to_datetime(sp500_data.index)
    
    sp500_data.to_csv("SP500.csv")
    
    sp500_units_for_1M = round(1000000/sp500_data.at['2015-01-02', 'Open'])
    #print(sp500_units_for_1M)
    
    df.index = df.index.date
    
    df['SP_500'] = sp500_data['Close']
    df['SP_500_Value'] = sp500_units_for_1M * df['SP_500']
    
    return df

# %%
result_df = calculate_SP_500_value(result_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
def calculate_metrics(df):
    #Calculation of returns
    initial_portfolio_value = 1000000 #1M was split and invested equally initially
    print("Initial Investment: ", initial_portfolio_value)
    print("------------------------------------------------")
    #strategy
    final_portfolio_value = result_df.at[result_df.index[-1], 'Portfolio Value']
    strategy_returns = ((final_portfolio_value-initial_portfolio_value)/(initial_portfolio_value)) * 100
    print("Final strategy portfolio value: ", final_portfolio_value)
    print("Strategy Returns: ", round(strategy_returns, 2), "%")
    print("------------------------------------------------")
    #no_strategy
    final_ns_portfolio_value = result_df.at[result_df.index[-1], 'NS Portfolio Value']
    ns_strategy_returns = ((final_ns_portfolio_value-initial_portfolio_value)/(initial_portfolio_value)) * 100
    print("Final equal split portfolio value: ", final_ns_portfolio_value)
    print("No Strategy Returns (Equal Split): ", round(ns_strategy_returns, 2), "%")
    print("------------------------------------------------")
    #S&P500
    final_sp500_value = result_df.at[result_df.index[-1], 'SP_500_Value']
    sp500_returns = ((final_sp500_value-initial_portfolio_value)/(initial_portfolio_value)) * 100
    print("Final SP_500 value: ", final_sp500_value)
    print("SP 500 Returns: ", round(sp500_returns, 2), "%")
    print("------------------------------------------------")
    #Annualized returns CAGR
    annualised_strategy_returns = ((1 + (strategy_returns/100)) ** (1/5)) - 1
    annualised_ns_returns = ((1 + (ns_strategy_returns/100)) ** (1/5)) - 1
    annualised_sp_returns = ((1 + (sp500_returns/100)) ** (1/5)) - 1
    
    print(f"Strategy returns (Annualised): {annualised_strategy_returns * 100:.2f}%")
    print(f"No Strategy returns (Annualised): {annualised_ns_returns * 100:.2f}%")
    print(f"SP returns (Annualised): {annualised_sp_returns * 100:.2f}%")
    
    df['Strategy_Portfolio_DReturns'] = df['Portfolio Value'].pct_change()
    df['NS_Portfolio_DReturns'] = df['NS Portfolio Value'].pct_change()
    df['SP_500_DReturns'] = df['SP_500_Value'].pct_change()
    
    #Calculation of risk
    strategy_risk = df['Strategy_Portfolio_DReturns'].std()
    ns_risk = df['NS_Portfolio_DReturns'].std()
    sp_500_risk = df['SP_500_DReturns'].std()
    print("------------------------------------------------")
    print(f"Strategy risk (Daily): {strategy_risk * 100:.2f}%")
    print(f"No Strategy risk (Daily): {ns_risk * 100:.2f}%")
    print(f"SP 500 (Daily): {sp_500_risk * 100:.2f}%")
    print("------------------------------------------------")
    print(f"Strategy risk (Monthly): {strategy_risk * np.sqrt(21) * 100:.2f}%")
    print(f"No Strategy risk (Monthly): {ns_risk * np.sqrt(21) * 100:.2f}%")
    print(f"SP 500 risk (Monthly): {sp_500_risk * np.sqrt(21) * 100:.2f}%")
    print("------------------------------------------------")
    print(f"Strategy risk (Annualised): {strategy_risk * np.sqrt(252) * 100:.2f}%")
    print(f"No Strategy risk (Annualised): {ns_risk * np.sqrt(252) * 100:.2f}%")
    print(f"SP 500 risk (Annualised): {sp_500_risk * np.sqrt(252) * 100:.2f}%")
    print("------------------------------------------------")
    
    print("Performance metrics of the Strategy")
    #Calculating Sharpe ratio of strategy
    annualised_strategy_risk = strategy_risk * np.sqrt(252)
    risk_free_rate = 0.0227 #calculated as the average yield of the 10-year t-bill rate over the given 5 year period
    sharpe_ratio = (annualised_strategy_returns - risk_free_rate)/annualised_strategy_risk
    print(f"Sharpe Ratio : {sharpe_ratio:.2f}")
    #Calculating Sortino ratio of strategy
    negative_daily_returns = df['Strategy_Portfolio_DReturns'][df['Strategy_Portfolio_DReturns'] < 0]
    downside_deviation = np.std(negative_daily_returns) * np.sqrt(252)
    sortino_ratio = (annualised_strategy_returns - risk_free_rate) / downside_deviation
    print(f"Sortino Ratio: {sortino_ratio:.2f}")
    #Calculating beta of the strategy
    covariance = df['Strategy_Portfolio_DReturns'].cov(df['SP_500_DReturns'])
    market_variance = df['SP_500_DReturns'].var()
    beta = covariance / market_variance
    print(f"Beta of the Strategy: {beta:.2f}")
    #Calculating alpha of the strategy
    alpha = annualised_strategy_returns - (risk_free_rate + beta * (annualised_sp_returns - risk_free_rate))
    print(f"Alpha of the Strategy: {alpha:.4f}")
    print("------------------------------------------------")
    return df

# %%
#Print the returns and metrics
result_df = calculate_metrics(result_df)
# Out:
# Initial Investment:  1000000
# ------------------------------------------------
# Final strategy portfolio value:  4567198.24156189
# Strategy Returns:  356.72 %
# ------------------------------------------------
# Final equal split portfolio value:  4090330.17137146
# No Strategy Returns (Equal Split):  309.03 %
# ------------------------------------------------
# Final SP_500 value:  1565546.958984375
# SP 500 Returns:  56.55 %
# ------------------------------------------------
# Strategy returns (Annualised): 35.50%
# No Strategy returns (Annualised): 32.54%
# SP returns (Annualised): 9.38%
# ------------------------------------------------
# Strategy risk (Daily): 1.49%
# No Strategy risk (Daily): 1.56%
# SP 500 (Daily): 0.85%
# ------------------------------------------------
# Strategy risk (Monthly): 6.82%
# No Strategy risk (Monthly): 7.15%
# SP 500 risk (Monthly): 3.88%
# ------------------------------------------------
# Strategy risk (Annualised): 23.63%
# No Strategy risk (Annualised): 24.76%
# SP 500 risk (Annualised): 13.44%
# ------------------------------------------------
# Performance metrics of the Strategy
# Sharpe Ratio : 1.41
# Sortino Ratio: 2.01
# Beta of the Strategy: 1.27
# Alpha of the Strategy: 0.2419
# ------------------------------------------------

# %%
result_df.to_csv("result_v1.csv")

# %%
plt.figure(figsize=(10, 6))  # Set the figure size (optional)
plt.plot(result_df.index, result_df['Portfolio Value'], label='Strategy', color='blue')  # Line for Column1
plt.plot(result_df.index, result_df['NS Portfolio Value'], label='Equal-Split', color='green')  # Line for Column2
plt.plot(result_df.index, result_df['SP_500_Value'], label='SP_500_Value', color='red')  # Line for Column3

# Adding title and labels
plt.title('Portfolio Value of Strategy, Equal Split and SP_500')
plt.xlabel('Date')
plt.ylabel('Value')

# Show legend
plt.legend()

# Display the plot
plt.show()

# %%
# Cumulative Max
result_df['Maximum Value'] = result_df['Portfolio Value'].cummax()

# Store the differences in a new colum "drawdowns"
# Note that we are calculating the drawdowns from cumsum of returns which is already in percentage.
result_df['Drawdown'] = result_df['Portfolio Value'] - result_df['Maximum Value']
result_df['Drawdown (%)'] = result_df['Drawdown']/result_df['Maximum Value']
result_df['Maximum Drawdown'] = result_df['Drawdown'].cummin()

# The maximum difference is refered as "Drawdown"
max_drawdown = result_df['Drawdown'].min()
max_drawdown_percent = result_df['Drawdown (%)'].min()
print("The max drawdown is", max_drawdown, "or", str(round(max_drawdown_percent*100,2))+"%")

#Visualise how these two look like
plt.figure(figsize=(10, 5))
result_df[['Portfolio Value', 'Maximum Value']].dropna().plot()
plt.xlabel('Date')  # X-axis label
plt.ylabel('Value')  # Y-axis label
plt.title('Portfolio Value vs. Maximum Value')  # Adding a title for clarity
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
result_df[['Drawdown', 'Maximum Drawdown']].dropna().plot()
plt.xlabel('Date')  # X-axis label
plt.ylabel('Drawdown Value')  # Y-axis label
plt.title('Drawdown vs. Maximum Drawdown')  # Adding a title for clarity
plt.legend()
plt.show()
# Out:
# The max drawdown is -1259734.109260559 or -28.8%
